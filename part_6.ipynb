# %%
# wap to print all the factor in given number.

# %%
num = int(input("Enter a number: "))
for i in range(1,num+1):
    if num % i == 0:
        print(i)
# Out:
# 1
# 2
# 4
# 8

# %%
# wap to count number of factors present for a given numbers

# %%
num = int(input("Enter a number: "))
count = 0
for i in range(1,num+1):
    if num % i == 0:
       count = count + 1
print(i)
# Out:
# 7

# %%
# wap to chack wether a given number is prime or not.

# %%
num = int(input("Enter a number: "))
for i in range(1,num+1):
    if num % i == 0:
        count=count+1
if count == 2:
    print(num)
else:
    print(num)
# Out:
# 3

# %%
# wap to input to print all the prime numbers between 5 to 20.

# %%
num = int(input("Enter a number: "))
count = 0
for i in range(1,num+1):
    if num%i == 0:
        count = count + 1
if count == 2:
    print(num)
# Out:
# 5

# %%
# wap to print all the prime numbers buttween a given range

# %%
start = int(input("Enter a number: "))
stop = int(input("Enter a number: "))

for i in range(start,stop+1):
    if i % 2 == 0:
        print(i)
