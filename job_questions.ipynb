# %%
# wap to solve the given below req.
# input (we are learn python and it is easy to learn)
# op (learn to easy is it and python learning are we)

# %%
S = input("enter the string")
l=S.split()
res=l[::-1]
output=(" ".join(res))
print(output)
# Out:
# kunal is name my

# %%
# wap to solve the given below req.
# Ip ( we love to code in python.
# we evol to eode in nohthon.

# %%
S = input("enter the string")
res=[]
s = 0
i=0
while i<=len(S)-1:
    if i %2==0:
        res.append(S[i])
else:
        res.append(S)
        i+=1

output=(" ".join(res))
print(output)
# Out:
# kunal is name my

# %%
# to solve the given below requirement.
# ip we love to code in python
# op n ni edoc ot evol ew

# %%
S = input("enter the string")[::-1]
print(S)
