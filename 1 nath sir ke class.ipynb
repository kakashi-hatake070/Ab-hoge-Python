# %%
from operator import truth

y = int(input("enter your year"))

if y % 4 == 0:
    if y % 100 == 0:
        if y % 400 == 0:
            print(y)

# %%
a = int(input("enter your 1 number"))
b = int(input("enter your 2 number"))
c = input("enter your symbol ")
if c == "+":
    print(a + b)
elif c == "-":
    print(a - b)
elif c == "*":
    print(a * b)
elif c == "/":
    print(a / b)
else:
    (print("Invalid input"))
# Out:
# 9

# %%
stud = float(input("enter your student"))
if stud >=90:
    grade = "A"
elif stud >=75:
    grade = "B"
elif stud >=60:
    grade = "c"
elif stud >=40:
    grade = "D"
else:
    print("won my boy this world is your")

# %%
ch = input("Enter your choice: ")

if ch.isalpha():
    if ch in "AEIOUaeiou":
        print("It is a vowel.")
    else:
        print("It is a consonant.")
else:
    print("It is not an alphabet.")

# %%
b = int(input("enter your age"))
if b > 21 :
    print("you are poor ")
if b >= 30 :
 print("you are rich")
else:
 print("kama  aaj kamiga to kal beth ke khiga aaaa mneri jaaan")

# %%
b = int(input("enter your bonus salary"))
y = int(input("enter your year you spand"))
if b > 5000 :
    print("you are allowed to take bonus")
if y > 5:
    print("you are not allowed to take a bonus")
else:
    print("the my questions said")

# %%
stud = float(input("enter the student grade"))
if stud >= 35:
    print("Pass")
if stud >= 90:
    print("your grade is A")
    if stud >= 75:
        print("your grade is B")
        if stud >= 60:
            print("your grade is C")
            if stud >= 35:
                print("your grade is D")
else:
    print("Fail")

# %%
stud = float(input("Enter the student grade: "))

if stud >= 35:
    print("Pass")

    if stud >= 90:
        print("Your grade is A")
    elif stud >= 75:
        print("Your grade is B")
    elif stud >= 60:
        print("Your grade is C")
    else:
        print("Your grade is D")

else:
    print("Fail")

# %%
# 24. Age group
age = int(input("Age: "))

if age >= 60:
    print("Senior citizen")
elif age >= 20:
    print("Adult")
elif age >= 12:
    print("Teenager")
else:
    print("Child")

# %%
i = 1
while i<=10:
   # if i 1%2 ==0:

    print(i)
    i = i+1

# %%
k = 1
while k<=10:
    if  k%2!=0:
        print(k)
    k+=1

# %%
start = int(input("enter your start year"))
stop = int(input("enter your stop year"))
i = start
while i<=stop:
    print(i)
    i+=1

# %%
i = 1
while i<=7:
   if k%2!=0:
       print(i+5)
else:
    print(1*5)

    print(i)
    i+=1

# %%
even_sum = 0
odd_product = 1
for i in range(1, 8):
    if i % 2 == 0:
        even_sum += i
    else:
        odd_product *= i

print(f"Sum of even numbers: {even_sum}")
print(f"Product of odd numbers: {odd_product}")

# %%
k = 122
while k>=97:
    print(chr(k))
    k = (k -1)

# %%
k = 65
while k<=90:
    print(chr(k))
    k = (k +1)

# %%
k = 1
while k<=10:
    print("7 x",k,"=",7*k)
    k= k+1

# %%
k = int(input("enter a number"))
i = 1
while i<=10:
        print(k,"x",i,"=",k*i)
        i=i+1

# %%
i=1
Sum=0
while i<=5:
    Sum=Sum+i
    i=i+1
print(Sum)

# %%
i=1
s=1
while i<=5:
    s =s*i
    i=i+1
print(s)

# %%
i = 1
z = 0
while i<=10:
    if i%2==0:
     z=z+i
    i=i+1
print(z)

# %%
i = 5
z = 1
while i<=15:
    if i%2!=0:
        z=z*i
    i=i+1
print(z)

# %%
num = int(input("enter a number"))
count = 0

while num!=0:
    count=count+1
    num = num//10
print(count)
# Out:
# 10

# %%
char = input("enter a character")
count = 0
for letter in char:
    count=count+1
print(count)
